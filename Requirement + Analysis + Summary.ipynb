# %% [markdown]
# # Employee Performance Analysis

# %% [markdown]
# # 1 : Requirement
#
# The data is based on INX Future Inc, It is one of the leading data analytics and automation solutions provider with over 15 years of global business presence, It is not from the real organization. I've done the whole project in Jupiter notebook.

# %% [markdown]
# # 2 : Analysis
#
# ### <u> Categorical Features </u>
#
#    - Gender
#    - EducationBackground
#    - MaritalStatus
#    - EmpDepartment
#    - EmpJobRole
#    - BusinessTravelFrequency
#    - EmpEducationLevel
#    - EmpEnvironmentSatisfaction
#    - EmpJobInvolvement
#    - EmpJobLevel
#    - EmpJobSatisfaction
#    - OverTime
#    - EmpRelationshipSatisfaction
#    - EmpWorkLifeBalance
#    - Attrition
#    - PerformanceRating
#
# ### <u> Numerical Features </u>
#
#
#    - Age
#    - DistanceFromHome
#    - EmpHourlyRate
#    - NumCompaniesWorked
#    - EmpLastSalaryHikePercent
#    - TotalWorkExperienceInYears
#    - TrainingTimesLastYear
#    - ExperienceYearsAtThisCompany
#    - ExperienceYearsInCurrentRole
#    - YearsSinceLastPromotion
#    - YearsWithCurrManager
#
# ### <u> Alphanumeric Features </u>
#
#    - Employee ID number
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
#
# ## Feauture analysis by columns order
#
# ###### EmpNumber(string) :
# - Its an alphanumeric string containg each employees unique Id there is total 1200 employes information in this dataset
#
# ###### Age(int64):
# - There is 43 Unique value in Age column.
# - minimun age is 18 , maximum is 60 , most frequent age is 34 , mean is 36
# - The age column is normally distributed
# - Employee between age 30 to 40 has good hourly rate.
#
# ###### Gender(string):
# - has 2 unique value
# - Male (725), Female (475)
# - Since male employees are more, performance ratings for men is high compared to women.
#
# ###### EducationBackground(string) :
# - has 6 unique values
# - Life Sciences (492), Medical (384), Marketing (137), Technical Degree (100), Other (66), Human Resources (21)
# - most of the empoyees are from medical related background(Life-science and Medical).
# - There are only few employees in  from Human Resource compared to other department.
# - Human resource Educationalbackground has least performance ratings.
#
# ##### MaritalStatus(string)
# - has 3 unique values
# - Married (548), Single (384), Divorced (268)
# - performence is higher for employees who are single, than married and divorced.
#
# ##### EmpDepartment(string)
# - has 6 unique values
# - Sales (373), Development (361), Research & Development (343), Human Resources (54), Finance (49), Data Science (20)
#
# ##### EmpJobRole(string)
# - has 19 uniques
# - Sales Executive roles are high while Technical Architect role is low.
# - Sales Executive (270), Developer (236), Manager R&D (94), Research Scientist (77), Sales Representative (69), Laboratory Technician (64), Senior Developer (52), Manager (51), Finance Manager (49), Human Resources (45), Technical Lead (38), Healthcare Representative (33), Manufacturing Director (33), Data Scientist (20), Research Director (19), Business Analyst (16), Senior Manager R&D (15), Delivery Manager (12), Technical Architect (7)
#
# ##### BusinessTravelFrequency(string)
# - has 3 uniques
# - Travel_Rarely (846), Travel_Frequently (222), Non-Travel (132)
#
# ##### DistanceFromHome(int64)
# - could be km or miles
# - values ranges from 1 to 29
# - mean is 9.1658
#
#
# ##### EmpEducationLevel(int64)
# - has 5 Uniques
# - 3 (449), 4 (322), 2 (239), 1 (148), 5 (42)
# - could be UG, PG, Diploma, Phd or additional course
#
# ##### EmpEnvironmentSatisfaction(int64)
# - has 4 Uniques
# - 3 (367), 4 (361), 2 (242), 1 (230)
# - could be high, low, average or low
#
# #### EmpHourlyRate(int64)
# - has 71 Uniques
# - values ranges between 30 to 100
# - mean is 65.9817
#
# ##### EmpJobInvolvement(int64)
# - has 4 Uniques
# - 3 (724), 2 (294), 4 (112), 1 (70)
# - could be high, low, average or low
#
# ##### EmpJobLevel(int64)
# - has 5 Uniques
# - 2 (441), 1 (440), 3 (173), 4 (90), 5 (56)
# - could be trainee, executive, sr.executive , manager or other job levels
#
# ##### EmpJobSatisfaction(int64)
# - has 4 Uniques
# - 4 (378), 3 (354), 2 (237), 1 (231)
# - could be high, low, average or low
#
# ##### NumCompaniesWorked(int64)
# - has 10 Uniques
# - values ranges between 0 to 9
# - mean is 2
#
# ##### OverTime(string)
# - has 2 Uniques
# - No (847), Yes (353)
# - depicts number of employees doing overtime
#
# #### EmpLastSalaryHikePercent(int64)
# - ranges betwen 11 to 25
# - has 15 uniques
# - mean:15.2225
#
# ##### EmpRelationshipSatisfaction(int64)
# - has 4 Unique
# - mean is 2.725
# - 3 (379), 4 (355), 2 (247), 1 (219)
# - could be high, low, average or poor
#
# #### TotalWorkExperienceInYears(int64)
# - ranges between 0 to 40
# - mean is 11.33
# - has 40 Uniques
#
# #### TrainingTimesLastYear(int64)
# - has 7 Uniques
# - ranges between 0 to 6
# - mean is 2.7858
#
# #### EmpWorkLifeBalance(int64)
# - has 4 uniques
# - mean is 2.7442
# - 3 (727), 2 (294), 4 (115), 1 (64)
# - could be high, low, average or low
#
# #### ExperienceYearsAtThisCompany(int64)
# - has Uniques 37
# - ranges between 0 to 40
# - mean is 7.0775
#
# ##### ExperienceYearsInCurrentRole(int64)
# - has 19 Unique
# - ranges between 0 to 18
# - mean:4.2917
#
# ##### YearsSinceLastPromotion(int64)
# - has 16 Unique
# - ranges between 0 to 15
# - mean is 2.1942
#
# ##### YearsWithCurrManager(int64)
# - has 18 Unique
# - ranges between 0 to 17
# - mean:4.105
#
# #### Attrition(string)
# - has 2 Unique
# - No (1022), Yes (178)
# - depicts number of employess resigning or retiring
# - Attrition, in Human Resource terminology, refers to the phenomenon of the employees leaving the company.
# - when distance from home increases for a employee, he/she is more likely to get leave the company.
# - attrition rate for males are high compared to female
#
# ##### PerformanceRating(int64)
# - has 3 uniques
# - ranges between 2 to 4
# - mean:2.9483
# - 3 (874), 2 (194), 4 (132)
# - could be high , medium and average

# %% [markdown]
# ## Cleaning
# - Did basic checks for duplicates and null values
#
# ## Encoding tecniques
# - encoded all object dtype column using Label encoder
#
# ## Target variable and dependent variables
# - used PerformanceRating as target variable
# - used all other columns as independent variable except EmpNumber cause since we have every other details about Employee we dont need EmpNumber, hence droped it
#
# ## Trainning and testing ratio
# - train size is 0.8
# - test size is 0.2
#
# ## Scaling technique
# - used standard scaler for scaling independent variable
#
# ## Machine Learning Model
# - Since the target variable is ordinal data, I'm using ML classifier models
# - Models used in this project:
#
#         1.Bagging Classifier
#         2.Random Forest Classifier
#         3.K-Nearest Neighbors Classifier
#         4.XGBoost Classifier
#         5.Support Vector Classifier
#         6.Decision Tree Classifier
#
# ## Metrics used for ML models
#         * accuracy
#         * confusion_matrix
#         * classification_report
#         * cross_val_score
#         * bagging_accuracy (bagging ensemble technique)
#
# ## Best ML model
# - Random Forest Classifier
# - cause compared to other models it has good
#         * accuracy score  = 0.94
#         * bagging score = 0.95
#         * cross validation = 0.92
#
# ## Hyper tunning
# - Since Random Forest Classifier is the best model I've hypertunned it
# - after hyper tunning
#         * accuracy score  = 0.95
#         * bagging score = 0.92
#         * cross validation = 0.92
#
# ## Future Importance
# - found Important futures for Random Forest Classifier model
# - Top 3 important futures are
#         1. Employee Last Salary Hike Percentage
#         2. Employment Environment Satisfaction
#         3. Years Since Last Promotion

# %% [markdown]
# # 3 : Summary
#
# INX Future Inc Employee Performance - Project
# INX Future Inc , (referred as INX ) , is one of the leading data analytics and automation solutions provider
# with over 15 years of global business presence. INX is consistently rated as top 20 best employers past 5
# years. INX human resource policies are considered as employee friendly and widely perceived as best
# practices in the industry.
# Recent years, the employee performance indexes are not healthy and this is becoming a growing
# concerns among the top management. There has been increased escalations on service delivery and
# client satisfaction levels came down by 8 percentage points.
# CEO, Mr. Brain, knows the issues but concerned to take any actions in penalizing non-performing
# employees as this would affect the employee morale of all the employees in general and may further
# reduce the performance. Also, the market perception best employer and thereby attracting best talents
# to join the company.
# Mr. Brain decided to initiate a data science project , which analyses the current employee data and find
# the core underlying causes of this performance issues. Mr. Brain, being a data scientist himself, expects
# the findings of this project will help him to take right course of actions. He also expects a clear indicators
# of non performing employees, so that any penalization of non-performing employee, if required, may
# not significantly affect other employee morals.
#
# ## The following insights are expected from this project.
#
# ### 1. Department wise performances
#
# - Since this dataset is imbalanced, I'm using percentage to caluclate the each deparatments performance.
# - performance range for each department is 4 ,3 and 2.
# - 4 is high performance, 3 is medium performance and 2 is low performance.
# - These are the departments.
#         1.Sales
#         2.Human Resources
#         3.Development
#         4.Data Science
#         5.Research & Development
#         6.Finance
# - Higher the 2, department is more likely to low in performance.
# - higher the 4 and 3 depertment is more likely to perform well.
#
# ##### Best performing department by order
#     1.Development
#     2.Data Science
#     3.Human Resources
#     4.Research & Development
#     5.Sales
#     6.Finance
#
# ### 2. Top 3 Important Factors effecting employee performance
#
# - I'v used future importance to get this
#
#         1. Employee Last Salary Hike Percentage
#         2. Employment Environment Satisfaction
#         3. Years Since Last Promotion
#
# ### 3. A trained model which can predict the employee performance based on factors as inputs. This will be used to hire employees
# - Random Forest Classifier is the best model for predicting employee performance
# - after hyper tunning Random Forest Classifier, the results are
#         * accuracy score  = 0.95
#         * bagging score = 0.92
#         * cross validation = 0.92
#
# ### 4. Recommendations to improve the employee performance based on insights from analysis.
#
#         1. Employee Last Salary Hike Percentage
#         2. Employment Environment Satisfaction
#         3. Years Since Last Promotion
# - Since these factors have great impact on employee performance, It's wise to improve them, which mean more salary hike, improving environment and more promotions.
